# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-3, 3, 0.001)

# %%
x.shape
# Out:
# (6000,)

# %%
x[:10]
# Out:
# array([-3.   , -2.999, -2.998, -2.997, -2.996, -2.995, -2.994, -2.993,
#        -2.992, -2.991])

# %%
norm.pdf(x)
# Out:
# array([0.00443185, 0.00444516, 0.00445851, ..., 0.00447189, 0.00445851,
#        0.00444516])

# %%
x.std()
# Out:
# np.float64(1.7320507835124253)

# %%
plt.plot(x, norm.pdf(x))

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.14.1-cp310-cp310-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in ./.venv/lib/python3.10/site-packages (from scipy) (2.1.3)
# Downloading scipy-1.14.1-cp310-cp310-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: scipy
# Successfully installed scipy-1.14.1
# Note: you may need to restart the kernel to use updated packages.
